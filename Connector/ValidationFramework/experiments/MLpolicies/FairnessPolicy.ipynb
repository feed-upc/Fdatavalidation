# %%
import os

# %%
base_dir = os.getcwd()

base_dir = os.path.join(base_dir, '../')

# %%
# !pip install ipynb >> /dev/null
# !pip install nbformat >> /dev/null
# !pip install papermill >> /dev/null
# !pip install rdflib >> /dev/null
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import papermill as pm

from rdflib import *

# %%
# Set the current working directory to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath('__file__')))

# %% [markdown]
# # DATA VALIDATION FRAMEWORK

# %%
pm.execute_notebook(
    os.path.join(base_dir, '../../../FederatedComputationalGovernance/federated_layer_populator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, '../../../FederatedComputationalGovernance/'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]
# {'cells': [{'id': '99fa1749',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.344118',
#      'end_time': '2024-12-13T15:47:42.356120',
#      'duration': 0.012002,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:42.345672Z',
#      'iopub.execute_input': '2024-12-13T15:47:42.345935Z',
#      'shell.execute_reply': '2024-12-13T15:47:42.353388Z',
#      'iopub.status.idle': '2024-12-13T15:47:42.354251Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../FederatedComputationalGovernance/"\n',
#    'outputs': []},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.365547Z',
#      'start_time': '2024-09-09T09:24:03.345208Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.357114',
#      'end_time': '2024-12-13T15:47:42.369562',
#      'duration': 0.012448,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:42.359422Z',
#      'iopub.execute_input': '2024-12-13T15:47:42.360279Z',
#      'iopub.status.idle': '2024-12-13T15:47:42.366672Z',
#      'shell.execute_reply': '2024-12-13T15:47:42.365432Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': 'd0e619c55e236cce',
#    'outputs': [],
#    'execution_count': 2},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.369877',
#      'end_time': '2024-12-13T15:47:42.370191',
#      'duration': 0.000314,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Load Tbox',
#    'id': 'bf9b7f625c8aae1a'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.491590Z',
#      'start_time': '2024-09-09T09:24:03.370533Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.370358',
#      'end_time': '2024-12-13T15:47:42.451401',
#      'duration': 0.081043,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:42.372120Z',
#      'iopub.execute_input': '2024-12-13T15:47:42.372780Z',
#      'shell.execute_reply': '2024-12-13T15:47:42.448932Z',
#      'iopub.status.idle': '2024-12-13T15:47:42.449737Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import *',
#    'id': 'e75da1d8b860cfb8',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.821330Z',
#      'start_time': '2024-09-09T09:24:03.776497Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.451551',
#      'end_time': '2024-12-13T15:47:42.478253',
#      'duration': 0.026702,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:42.452663Z',
#      'iopub.execute_input': '2024-12-13T15:47:42.452911Z',
#      'shell.execute_reply': '2024-12-13T15:47:42.475747Z',
#      'iopub.status.idle': '2024-12-13T15:47:42.476568Z'}},
#    'cell_type': 'code',
#    'source': "g = Graph()\n\ng.parse(os.path.join(base_dir,'FederatedTeam/tbox.ttl'), format='ttl')\n\ng.bind('tb', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\ng.bind('ab', 'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')",
#    'id': 'bb71af78cd94ef67',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.479025',
#      'end_time': '2024-12-13T15:47:42.480008',
#      'duration': 0.000983,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# Populate ABOX',
#    'id': '7ff6593a3c2875a4'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:03.852508Z',
#      'start_time': '2024-09-09T09:24:03.838546Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.480286',
#      'end_time': '2024-12-13T15:47:42.491865',
#      'duration': 0.011579,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:42.482257Z',
#      'iopub.execute_input': '2024-12-13T15:47:42.482834Z',
#      'shell.execute_reply': '2024-12-13T15:47:42.488349Z',
#      'iopub.status.idle': '2024-12-13T15:47:42.489456Z'}},
#    'cell_type': 'code',
#    'source': "def add_jsonld_instances(graph, path):\n    # Adds JSON-LD instances to the graph\n    with open(path, 'r') as f:\n        json_ld_data = json.loads(f.read())\n        instances = Graph().parse(data=json_ld_data, format='json-ld')\n        graph += instances\n    \n    return graph",
#    'id': '4e3a545aa5415c94',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.219065Z',
#      'start_time': '2024-09-09T09:24:03.870463Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:42.492148',
#      'end_time': '2024-12-13T15:47:45.569676',
#      'duration': 3.077528,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:42.493886Z',
#      'iopub.execute_input': '2024-12-13T15:47:42.494444Z',
#      'iopub.status.idle': '2024-12-13T15:47:45.564429Z',
#      'shell.execute_reply': '2024-12-13T15:47:45.560839Z'}},
#    'cell_type': 'code',
#    'source': '!pip install rdflib_jsonld\nimport json',
#    'id': 'e830802a9f33a17',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib_jsonld in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (0.6.2)\r\nRequirement already satisfied: rdflib>=5.0.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib_jsonld) (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib>=5.0.0->rdflib_jsonld) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=5.0.0->rdflib_jsonld) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:45.571051',
#      'end_time': '2024-12-13T15:47:45.571831',
#      'duration': 0.00078,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Common Data Models',
#    'id': 'bd37775213d6baee'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.465235Z',
#      'start_time': '2024-09-09T09:24:06.448936Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:45.572118',
#      'end_time': '2024-12-13T15:47:45.585638',
#      'duration': 0.01352,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:45.575470Z',
#      'iopub.execute_input': '2024-12-13T15:47:45.576155Z',
#      'shell.execute_reply': '2024-12-13T15:47:45.581240Z',
#      'iopub.status.idle': '2024-12-13T15:47:45.582538Z'}},
#    'cell_type': 'code',
#    'source': "data_products = os.path.join(base_dir,'GlobalDefinitions/common_data_models.json')",
#    'id': 'ec4292618860beb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.545045Z',
#      'start_time': '2024-09-09T09:24:06.507117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:45.585908',
#      'end_time': '2024-12-13T15:47:45.606141',
#      'duration': 0.020233,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:45.587245Z',
#      'iopub.execute_input': '2024-12-13T15:47:45.587684Z',
#      'shell.execute_reply': '2024-12-13T15:47:45.603052Z',
#      'iopub.status.idle': '2024-12-13T15:47:45.603951Z'}},
#    'cell_type': 'code',
#    'source': 'g = add_jsonld_instances(g, data_products)',
#    'id': '6734503f59ccfc38',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:45.606327',
#      'end_time': '2024-12-13T15:47:45.606653',
#      'duration': 0.000326,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '## Policies',
#    'id': '6e49c23a901fe075'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.625802Z',
#      'start_time': '2024-09-09T09:24:06.563967Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:45.606825',
#      'end_time': '2024-12-13T15:47:45.626002',
#      'duration': 0.019177,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:45.608202Z',
#      'iopub.execute_input': '2024-12-13T15:47:45.608880Z',
#      'shell.execute_reply': '2024-12-13T15:47:45.622380Z',
#      'iopub.status.idle': '2024-12-13T15:47:45.623248Z'}},
#    'cell_type': 'code',
#    'source': "policies = os.path.join(base_dir,'ComputationalCatalogues')\nfor pc in os.listdir(policies):\n    g = add_jsonld_instances(g, os.path.join(policies, pc))",
#    'id': '61ffdb64b35b3f7f',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:45.626169',
#      'end_time': '2024-12-13T15:47:45.626488',
#      'duration': 0.000319,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': '# SAVE GRAPH',
#    'id': '5d6ee7446f360346'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-09T09:24:06.670677Z',
#      'start_time': '2024-09-09T09:24:06.641755Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:45.626644',
#      'end_time': '2024-12-13T15:47:45.653490',
#      'duration': 0.026846,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:45.628253Z',
#      'iopub.execute_input': '2024-12-13T15:47:45.628683Z',
#      'iopub.status.idle': '2024-12-13T15:47:45.651670Z',
#      'shell.execute_reply': '2024-12-13T15:47:45.650688Z'}},
#    'cell_type': 'code',
#    'source': "g.serialize(destination=os.path.join(base_dir,'SemanticDataModel/sdm.ttl'), format='ttl')",
#    'id': '215d623c22129341',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N0e1d226b84334c40a1411b26d3f5e1d4 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 10}],
#    'execution_count': 10}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../FederatedComputationalGovernance/'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../FederatedComputationalGovernance/federated_layer_populator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-13T15:47:41.413746',
#    'end_time': '2024-12-13T15:47:45.873107',
#    'duration': 4.459361,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ### Data product Registration

# %% [markdown]
# #### DP1 (ML Model)

# %%
file_path = r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl"

# %%
pm.execute_notebook(
    os.path.join(base_dir, '../../../DataPlatformLayer/Registration/profiler.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, '../../../DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# {'cells': [{'id': '325b378c',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:46.907184',
#      'end_time': '2024-12-13T15:47:46.928356',
#      'duration': 0.021172,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:46.911145Z',
#      'iopub.execute_input': '2024-12-13T15:47:46.912011Z',
#      'shell.execute_reply': '2024-12-13T15:47:46.924209Z',
#      'iopub.status.idle': '2024-12-13T15:47:46.925770Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:46.929300',
#      'end_time': '2024-12-13T15:47:55.374370',
#      'duration': 8.44507,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:46.931249Z',
#      'iopub.execute_input': '2024-12-13T15:47:46.931778Z',
#      'iopub.status.idle': '2024-12-13T15:47:55.372193Z',
#      'shell.execute_reply': '2024-12-13T15:47:55.371018Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:55.375595',
#      'end_time': '2024-12-13T15:47:55.577206',
#      'duration': 0.201611,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:55.377743Z',
#      'iopub.execute_input': '2024-12-13T15:47:55.378240Z',
#      'shell.execute_reply': '2024-12-13T15:47:55.573990Z',
#      'iopub.status.idle': '2024-12-13T15:47:55.574789Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:55.578272',
#      'end_time': '2024-12-13T15:47:55.652866',
#      'duration': 0.074594,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:55.579535Z',
#      'iopub.execute_input': '2024-12-13T15:47:55.579932Z',
#      'shell.execute_reply': '2024-12-13T15:47:55.650443Z',
#      'iopub.status.idle': '2024-12-13T15:47:55.651231Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:55.653127',
#      'end_time': '2024-12-13T15:47:56.429365',
#      'duration': 0.776238,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:55.654318Z',
#      'iopub.execute_input': '2024-12-13T15:47:55.654566Z',
#      'shell.execute_reply': '2024-12-13T15:47:56.426811Z',
#      'iopub.status.idle': '2024-12-13T15:47:56.427574Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            se ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:56.430461',
#      'end_time': '2024-12-13T15:47:56.438365',
#      'duration': 0.007904,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:56.431755Z',
#      'iopub.execute_input': '2024-12-13T15:47:56.432075Z',
#      'iopub.status.idle': '2024-12-13T15:47:56.436003Z',
#      'shell.execute_reply': '2024-12-13T15:47:56.434803Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:56.438526',
#      'end_time': '2024-12-13T15:47:56.446447',
#      'duration': 0.007921,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:56.439802Z',
#      'iopub.execute_input': '2024-12-13T15:47:56.440674Z',
#      'iopub.status.idle': '2024-12-13T15:47:56.444528Z',
#      'shell.execute_reply': '2024-12-13T15:47:56.443570Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:56.446719',
#      'end_time': '2024-12-13T15:47:56.460228',
#      'duration': 0.013509,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:56.447938Z',
#      'iopub.execute_input': '2024-12-13T15:47:56.448187Z',
#      'iopub.status.idle': '2024-12-13T15:47:56.458097Z',
#      'shell.execute_reply': '2024-12-13T15:47:56.457059Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'OTHERFIle /home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv\n'}],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:56.460459',
#      'end_time': '2024-12-13T15:47:56.468087',
#      'duration': 0.007628,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:56.461564Z',
#      'iopub.execute_input': '2024-12-13T15:47:56.461875Z',
#      'iopub.status.idle': '2024-12-13T15:47:56.466389Z',
#      'shell.execute_reply': '2024-12-13T15:47:56.465383Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:56.468339',
#      'end_time': '2024-12-13T15:47:56.468589',
#      'duration': 0.00025,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:56.468823',
#      'end_time': '2024-12-13T15:47:56.488857',
#      'duration': 0.020034,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:56.469757Z',
#      'iopub.execute_input': '2024-12-13T15:47:56.469979Z',
#      'iopub.status.idle': '2024-12-13T15:47:56.487016Z',
#      'shell.execute_reply': '2024-12-13T15:47:56.486009Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:56.489110',
#      'end_time': '2024-12-13T15:47:56.532796',
#      'duration': 0.043686,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:56.490288Z',
#      'iopub.execute_input': '2024-12-13T15:47:56.490566Z',
#      'shell.execute_reply': '2024-12-13T15:47:56.530062Z',
#      'iopub.status.idle': '2024-12-13T15:47:56.530914Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=Nc77c31744a0d4f65b8f0a4bd02adf12a (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/model.pkl'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-13T15:47:46.003322',
#    'end_time': '2024-12-13T15:47:56.854532',
#    'duration': 10.85121,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# #### DP2 (TEST DATASET)

# %%
file_path =r"/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv"

# %%
pm.execute_notebook(
    os.path.join(base_dir, '../../../DataPlatformLayer/Registration/profiler.ipynb'), None, parameters={
        'folder': os.path.join(base_dir, '../../../DataPlatformLayer/Registration'),
        'file_path': file_path
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: file_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/12 [00:00<?, ?cell/s]
# {'cells': [{'id': 'b7829089',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:58.093363',
#      'end_time': '2024-12-13T15:47:58.117167',
#      'duration': 0.023804,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:58.097288Z',
#      'iopub.execute_input': '2024-12-13T15:47:58.098065Z',
#      'iopub.status.idle': '2024-12-13T15:47:58.114678Z',
#      'shell.execute_reply': '2024-12-13T15:47:58.113422Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Registration"\nfile_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-11-27T18:21:07.187336Z',
#      'start_time': '2024-11-27T18:20:58.874104Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:47:58.118193',
#      'end_time': '2024-12-13T15:48:08.242750',
#      'duration': 10.124557,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:47:58.120497Z',
#      'iopub.execute_input': '2024-12-13T15:47:58.121491Z',
#      'shell.execute_reply': '2024-12-13T15:48:08.237912Z',
#      'iopub.status.idle': '2024-12-13T15:48:08.239550Z'}},
#    'source': '!pip install rdflib\n!pip install pandas\n!pip install pydicom',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: rdflib in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (7.0.0)\r\nRequirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (0.6.1)\r\nRequirement already satisfied: pyparsing<4,>=2.1.0 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from rdflib) (3.1.4)\r\nRequirement already satisfied: six in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pandas in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.1.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: numpy<2,>=1.23.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (1.26.4)\r\nRequirement already satisfied: python-dateutil>=2.8.2 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)\r\nRequirement already satisfied: pytz>=2020.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: tzdata>=2022.1 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from pandas) (2024.1)\r\nRequirement already satisfied: six>=1.5 in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Requirement already satisfied: pydicom in /home/acraf/psr/Fdatavalidation/venv/lib/python3.11/site-packages (2.4.4)\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.200159Z',
#      'start_time': '2024-11-27T18:21:07.194361Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:08.243994',
#      'end_time': '2024-12-13T15:48:08.457618',
#      'duration': 0.213624,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:08.246314Z',
#      'iopub.execute_input': '2024-12-13T15:48:08.246831Z',
#      'shell.execute_reply': '2024-12-13T15:48:08.454140Z',
#      'iopub.status.idle': '2024-12-13T15:48:08.455420Z'}},
#    'cell_type': 'code',
#    'source': 'import os, pickle, joblib\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '4bcc94b4b5f1eb3e',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.254327Z',
#      'start_time': '2024-11-27T18:21:07.248403Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:08.458435',
#      'end_time': '2024-12-13T15:48:08.559015',
#      'duration': 0.10058,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:08.460214Z',
#      'iopub.execute_input': '2024-12-13T15:48:08.460983Z',
#      'iopub.status.idle': '2024-12-13T15:48:08.556201Z',
#      'shell.execute_reply': '2024-12-13T15:48:08.554917Z'}},
#    'cell_type': 'code',
#    'source': "from rdflib import *\nfrom hashlib import sha256\ntbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': '4a670ddc66769fa1',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.335167Z',
#      'start_time': '2024-11-27T18:21:07.301053Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:08.560104',
#      'end_time': '2024-12-13T15:48:09.130857',
#      'duration': 0.570753,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:08.562272Z',
#      'iopub.execute_input': '2024-12-13T15:48:08.562684Z',
#      'iopub.status.idle': '2024-12-13T15:48:09.128546Z',
#      'shell.execute_reply': '2024-12-13T15:48:09.127552Z'}},
#    'cell_type': 'code',
#    'source': '#Profiler Class\nimport os\nimport pandas as pd\nimport pydicom\nclass Profiler:\n    \n    def __init__(self, file_path, owner="Unknown"):\n        self.file_path = file_path\n        self.source_graph = self.create_graph()\n        self.datasetname = self.self_get_dataset_name()\n        self.set_owner = self.set_owner(owner)\n        self.file_extension = self.get_file_extension()\n        self.technology = self.add_technology()\n        self.source_graph = self.extract_metadata()\n        \n    def create_graph(self):\n        """\n        This function returns a graph object with the necessary prefixes\n        :return: RDF Graph\n        """\n        g = Graph()\n        g.bind(\'tb\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#\')\n        g.bind(\'ab\', \'http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#\')\n        return g\n    \n    def set_owner(self, owner):\n        # Owner Metadata\n        self.source_graph.add((abox[self.datasetname],  tbox.owner, Literal(owner)))\n        return owner\n    \n    def self_get_dataset_name(self):\n        \n        name = os.path.basename(self.file_path).replace(\'.\', \'\')\n        # Name Metadata\n        self.source_graph.add((abox[name], RDF.type, tbox.DataProduct))\n        identifier = sha256(name.encode(\'utf-8\')).hexdigest()\n        self.source_graph.add((abox[name],dcterms.identifier, Literal(identifier)))\n        return name\n        \n\n    def get_file_extension(self):\n        file_name, file_extension = os.path.splitext(self.file_path)\n        format = abox.Tabular\n        if file_extension.lower() == \'.csv\':\n            format = abox.Tabular\n        elif file_extension.lower() == \'.dcm\':\n            format = abox.Image\n        elif file_extension.lower() == \'.pkl\':\n            format = abox.ML\n        \n        # DataSetTypeTemplate Metadata\n        self.source_graph.add((format, RDF.type, tbox.DatasetTypeTemplate))\n        self.source_graph.add((format, dcterms[\'format\'], Literal(file_extension)))  # Correct usage of the namespace\n        self.source_graph.add((abox[self.datasetname], tbox.hasDTT, format))\n\n        return file_extension.lower()\n    \n    def generate_unique_uri(self, base_uri):\n        import uuid\n        unique_identifier = str(uuid.uuid4())\n        return URIRef(f"{base_uri}{unique_identifier}")\n    \n    def add_technology(self):\n        #triple\n        self.source_graph.add((abox[self.datasetname+"_TA"], RDF.type, tbox.TechnologyAspects))\n        self.source_graph.add((abox[self.datasetname], tbox.hasTA, abox[self.datasetname+"_TA"]))\n\n        acces_uri = self.generate_unique_uri(abox)\n        self.source_graph.add((abox[self.datasetname+"_TA"], tbox.typeAcces, acces_uri))\n        self.source_graph.add((acces_uri, RDF.type, tbox.Acces))\n        self.source_graph.add((acces_uri, RDFS.label, abox.Static))\n        # PATH\n        self.source_graph.add((acces_uri, tbox.path, Literal(self.file_path)))\n\n    def extract_metadata(self):\n        if self.file_extension.lower() == \'.csv\':\n            return self.extract_csv_metadata()\n        elif self.file_extension.lower() == \'.dcm\':\n            return self.extract_dicom_metadata()\n        elif self.file_extension.lower() == \'.pkl\':\n            return self.extract_csv_metadata(os.path.join(os.path.dirname(self.file_path), "test.csv"))\n        else:\n            raise ValueError(f"Unsupported file extension: {self.file_extension}")\n            \n            \n    def extract_csv_metadata(self, other_file=""):\n        if other_file:\n            print("OTHERFIle", other_file)\n            df = pd.read_csv(other_file)\n        else:\n            df = pd.read_csv(self.file_path)\n        for column in df.columns:\n            self.source_graph.add((abox[column], RDF.type, tbox.Attribute))\n            self.source_graph.add((abox[self.datasetname], tbox.hasAttribute, abox[column]))\n            se ...
#    'id': 'e77fc103b819f2e6',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.389159Z',
#      'start_time': '2024-11-27T18:21:07.385052Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:09.131910',
#      'end_time': '2024-12-13T15:48:09.142735',
#      'duration': 0.010825,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:09.133195Z',
#      'iopub.execute_input': '2024-12-13T15:48:09.134403Z',
#      'iopub.status.idle': '2024-12-13T15:48:09.139910Z',
#      'shell.execute_reply': '2024-12-13T15:48:09.138660Z'}},
#    'cell_type': 'code',
#    'source': '#file_path = "/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/SurvivalClassifier.pkl"',
#    'id': '9521ab93300bf588',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.447646Z',
#      'start_time': '2024-11-27T18:21:07.442165Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:09.142986',
#      'end_time': '2024-12-13T15:48:09.150649',
#      'duration': 0.007663,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:09.144321Z',
#      'iopub.execute_input': '2024-12-13T15:48:09.144998Z',
#      'iopub.status.idle': '2024-12-13T15:48:09.149030Z',
#      'shell.execute_reply': '2024-12-13T15:48:09.148377Z'}},
#    'cell_type': 'code',
#    'source': 'try:\n    if file_path:\n        file_path = os.path.join(base_dir, file_path)\nexcept:\n    file_path = input("Enter file path: ")\n',
#    'id': '2119ea7442e15d70',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.524714Z',
#      'start_time': '2024-11-27T18:21:07.501117Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:09.150854',
#      'end_time': '2024-12-13T15:48:09.165784',
#      'duration': 0.01493,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:09.152188Z',
#      'iopub.execute_input': '2024-12-13T15:48:09.153215Z',
#      'shell.execute_reply': '2024-12-13T15:48:09.161745Z',
#      'iopub.status.idle': '2024-12-13T15:48:09.162921Z'}},
#    'cell_type': 'code',
#    'source': 'profiler = Profiler(file_path)',
#    'id': '4a1279da5765e287',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:07.800218Z',
#      'start_time': '2024-11-27T18:21:07.795156Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:09.166066',
#      'end_time': '2024-12-13T15:48:09.174640',
#      'duration': 0.008574,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:09.167250Z',
#      'iopub.execute_input': '2024-12-13T15:48:09.168068Z',
#      'iopub.status.idle': '2024-12-13T15:48:09.172507Z',
#      'shell.execute_reply': '2024-12-13T15:48:09.171583Z'}},
#    'cell_type': 'code',
#    'source': 'graph = profiler.get_source_graph()',
#    'id': '47148389f4da0fe5',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:09.174928',
#      'end_time': '2024-12-13T15:48:09.175154',
#      'duration': 0.000226,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Graph to File',
#    'id': '76bdfc3fd87537c8'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078400462Z',
#      'start_time': '2024-11-27T18:09:08.666164Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:09.175412',
#      'end_time': '2024-12-13T15:48:09.204296',
#      'duration': 0.028884,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:09.177291Z',
#      'iopub.execute_input': '2024-12-13T15:48:09.177816Z',
#      'iopub.status.idle': '2024-12-13T15:48:09.201801Z',
#      'shell.execute_reply': '2024-12-13T15:48:09.200911Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'ad0deee8b965c21d',
#    'outputs': [],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-11-27T18:21:08.078718002Z',
#      'start_time': '2024-11-27T18:09:08.718396Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:09.204569',
#      'end_time': '2024-12-13T15:48:09.245481',
#      'duration': 0.040912,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:09.205729Z',
#      'iopub.execute_input': '2024-12-13T15:48:09.205975Z',
#      'shell.execute_reply': '2024-12-13T15:48:09.241866Z',
#      'iopub.status.idle': '2024-12-13T15:48:09.242742Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += graph\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': 'e92ec7fe443edd3',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N57948928b49c46c6b24871402aacb5f3 (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 11}],
#    'execution_count': 11}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Registration',
#     'file_path': '/home/acraf/psr/Fdatavalidation/DataProductLayer/DataProduct3/Data/Explotation/test.csv'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Registration/profiler.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-13T15:47:56.980252',
#    'end_time': '2024-12-13T15:48:09.666034',
#    'duration': 12.685782,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## Integration

# %%
pm.execute_notebook(
    os.path.join(base_dir, '../../../DataPlatformLayer/Integration/federator.ipynb'),None, parameters={
        'folder':  os.path.join(base_dir, '../../../DataPlatformLayer/Integration'),
        'dp_meta_path': os.path.join(base_dir, '../../../DataPlatformLayer/Integration/dp3.json'),
    },
    log_output=False
)
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp_meta_path
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/17 [00:00<?, ?cell/s]
# {'cells': [{'id': '528acf65',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:10.753215',
#      'end_time': '2024-12-13T15:48:10.766992',
#      'duration': 0.013777,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:10.755297Z',
#      'iopub.execute_input': '2024-12-13T15:48:10.755787Z',
#      'iopub.status.idle': '2024-12-13T15:48:10.764038Z',
#      'shell.execute_reply': '2024-12-13T15:48:10.763063Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nfolder = "/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Integration"\ndp_meta_path = "/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Integration/dp3.json"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'id': 'initial_id',
#    'metadata': {'collapsed': True,
#     'ExecuteTime': {'end_time': '2024-09-12T11:01:22.459884Z',
#      'start_time': '2024-09-12T11:01:22.346667Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:10.768037',
#      'end_time': '2024-12-13T15:48:23.871869',
#      'duration': 13.103832,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:10.770298Z',
#      'iopub.execute_input': '2024-12-13T15:48:10.771223Z',
#      'iopub.status.idle': '2024-12-13T15:48:23.868824Z',
#      'shell.execute_reply': '2024-12-13T15:48:23.867658Z'}},
#    'source': '!pip install rdflib >> /dev/null\n!pip install pandas >> /dev/null\n!pip install pydicom >> /dev/null\n!pip install rdflib_jsonld >> /dev/null',
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b A new release of pip is available: \x1b\x1b23.2.1\x1b\x1b -> \x1b\x1b24.3.1\x1b\r\n\x1b[\x1b\x1bnotice\x1b\x1b[1;39;49m]\x1b\x1b To update, run: \x1b\x1bpip install --upgrade pip\x1b\r\n'}],
#    'execution_count': 2},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.505762Z',
#      'start_time': '2024-09-12T11:01:22.492797Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:23.873243',
#      'end_time': '2024-12-13T15:48:23.885451',
#      'duration': 0.012208,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:23.875840Z',
#      'iopub.execute_input': '2024-12-13T15:48:23.876410Z',
#      'shell.execute_reply': '2024-12-13T15:48:23.882239Z',
#      'iopub.status.idle': '2024-12-13T15:48:23.883391Z'}},
#    'cell_type': 'code',
#    'source': 'import os\n\n# Get the directory of the current script\nbase_dir = os.getcwd()\ntry:\n    if folder:\n        base_dir = os.path.join(base_dir, folder)\nexcept:\n    pass',
#    'id': '8bfa22744d99d563',
#    'outputs': [],
#    'execution_count': 3},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.536691Z',
#      'start_time': '2024-09-12T11:01:22.518729Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:23.885688',
#      'end_time': '2024-12-13T15:48:23.978809',
#      'duration': 0.093121,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:23.887239Z',
#      'iopub.execute_input': '2024-12-13T15:48:23.887656Z',
#      'shell.execute_reply': '2024-12-13T15:48:23.976448Z',
#      'iopub.status.idle': '2024-12-13T15:48:23.977184Z'}},
#    'cell_type': 'code',
#    'source': 'from rdflib import * \nimport uuid\nfrom hashlib import sha256\nimport json',
#    'id': 'e6137dfebf5fa7a8',
#    'outputs': [],
#    'execution_count': 4},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.568606Z',
#      'start_time': '2024-09-12T11:01:22.562623Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:23.979473',
#      'end_time': '2024-12-13T15:48:23.989309',
#      'duration': 0.009836,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:23.981477Z',
#      'iopub.execute_input': '2024-12-13T15:48:23.982321Z',
#      'shell.execute_reply': '2024-12-13T15:48:23.986697Z',
#      'iopub.status.idle': '2024-12-13T15:48:23.987590Z'}},
#    'cell_type': 'code',
#    'source': "tbox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#')\nabox = Namespace('http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#')\ndcat = Namespace('https://www.w3.org/ns/dcat#')\ndcterms = Namespace('http://purl.org/dc/terms/')\ndqv = Namespace('http://www.w3.org/ns/dqv#')",
#    'id': 'c55a560bcfa1619',
#    'outputs': [],
#    'execution_count': 5},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.599525Z',
#      'start_time': '2024-09-12T11:01:22.589552Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:23.989581',
#      'end_time': '2024-12-13T15:48:24.003002',
#      'duration': 0.013421,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:23.990575Z',
#      'iopub.execute_input': '2024-12-13T15:48:23.990806Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.000106Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.000908Z'}},
#    'cell_type': 'code',
#    'source': 'class Federator:\n    """\n        Federator class is responsible for federating the data from different sources.\n    """\n\n    def __init__(self, ds, SDM):\n        self.ds = ds\n        self.sdm = SDM \n\n    def check_dp_existance(self):\n        if self.sdm.value(predicate=RDF.type, subject=abox[self.ds]):\n            return True \n        else:\n            return False\n        \n    def generate_uri_id(self):\n        return str(uuid.uuid4())\n        \n    def add_mappings(self, mappings):\n        \n        # create contract\n        self.sdm.add((abox[f\'dc_{self.ds}\'],RDF.type, tbox.DataContract))\n        self.sdm.add((abox[self.ds],tbox.hasDC, abox[f\'dc_{self.ds}\']))\n        \n        # add mappings\n        for key, value in mappings.items(): # as key value pair dictionary\n            \n            # Generate mapping UUID\n            mapping_uuid = self.generate_uri_id()\n            self.sdm.add((abox[mapping_uuid], RDF.type, tbox.SchemaMapping))\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasMapping, abox[mapping_uuid]))\n            \n            # Add Mapping\n            self.sdm.add((abox[mapping_uuid], tbox.mfrom, abox[key]))\n            self.sdm.add((abox[mapping_uuid], tbox.mto, abox[value]))\n        \n        return self.sdm\n            \n            \n    def add_policies(self, policies):\n        # Add agreed policies\n        for policy in policies:\n            self.sdm.add((abox[f\'dc_{self.ds}\'],tbox.hasPolicy, abox[policy]))\n            \n        return self.sdm\n            \n        \n        ',
#    'id': '56029d96e9eca6ef',
#    'outputs': [],
#    'execution_count': 6},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.003307',
#      'end_time': '2024-12-13T15:48:24.003592',
#      'duration': 0.000285,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Run the Federator',
#    'id': 'f51c72bc145a251d'},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.003878',
#      'end_time': '2024-12-13T15:48:24.004124',
#      'duration': 0.000246,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Load SDM',
#    'id': '9e57d3fde81259df'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.646397Z',
#      'start_time': '2024-09-12T11:01:22.616478Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.004342',
#      'end_time': '2024-12-13T15:48:24.027748',
#      'duration': 0.023406,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:24.005774Z',
#      'iopub.execute_input': '2024-12-13T15:48:24.006118Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.024382Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.025197Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '7660a5e6cb8ca6fb',
#    'outputs': [],
#    'execution_count': 7},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.028010',
#      'end_time': '2024-12-13T15:48:24.028267',
#      'duration': 0.000257,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Data Product Metadata',
#    'id': 'f7f2ec147e852bf7'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.692278Z',
#      'start_time': '2024-09-12T11:01:22.677316Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.028502',
#      'end_time': '2024-12-13T15:48:24.036121',
#      'duration': 0.007619,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:24.029508Z',
#      'iopub.execute_input': '2024-12-13T15:48:24.030165Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.033166Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.033904Z'}},
#    'cell_type': 'code',
#    'source': "import json \ntry:\n    if dp_meta_path:\n        dp_meta = json.load(open(dp_meta_path))\n        dataset = dp_meta['name']\n        mappings = dp_meta['mappings']\n        policies = dp_meta['policies']\nexcept:\n    pass",
#    'id': '3a5a7bceb38b368f',
#    'outputs': [],
#    'execution_count': 8},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.754111Z',
#      'start_time': '2024-09-12T11:01:22.742145Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.036452',
#      'end_time': '2024-12-13T15:48:24.045427',
#      'duration': 0.008975,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:24.038177Z',
#      'iopub.execute_input': '2024-12-13T15:48:24.038638Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.042537Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.043575Z'}},
#    'cell_type': 'code',
#    'source': 'federator = Federator(dataset, sdm)',
#    'id': '3e44e3401a6e10d9',
#    'outputs': [],
#    'execution_count': 9},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:22.816945Z',
#      'start_time': '2024-09-12T11:01:22.795008Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.045678',
#      'end_time': '2024-12-13T15:48:24.054520',
#      'duration': 0.008842,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:24.046933Z',
#      'iopub.execute_input': '2024-12-13T15:48:24.047272Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.052334Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.051397Z'}},
#    'cell_type': 'code',
#    'source': 'print(federator.check_dp_existance())   ',
#    'id': '50452615c4e52a84',
#    'outputs': [{'output_type': 'stream', 'name': 'stdout', 'text': 'True\n'}],
#    'execution_count': 10},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.004772Z',
#      'start_time': '2024-09-12T11:01:22.989809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.054802',
#      'end_time': '2024-12-13T15:48:24.063825',
#      'duration': 0.009023,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:24.056078Z',
#      'iopub.execute_input': '2024-12-13T15:48:24.056450Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.060432Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.061367Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_mappings(mappings)',
#    'id': '8e89e751ac4203a8',
#    'outputs': [],
#    'execution_count': 11},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.051641Z',
#      'start_time': '2024-09-12T11:01:23.037679Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.064084',
#      'end_time': '2024-12-13T15:48:24.071116',
#      'duration': 0.007032,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:24.065247Z',
#      'iopub.execute_input': '2024-12-13T15:48:24.065466Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.068644Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.069210Z'}},
#    'cell_type': 'code',
#    'source': 'contract = federator.add_policies(policies)',
#    'id': '7234b70d592f1253',
#    'outputs': [],
#    'execution_count': 12},
#   {'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.071390',
#      'end_time': '2024-12-13T15:48:24.071656',
#      'duration': 0.000266,
#      'status': 'completed'}},
#    'cell_type': 'markdown',
#    'source': 'Save Contract that includes the specified Integration',
#    'id': '8584f22cc073451b'},
#   {'metadata': {'ExecuteTime': {'end_time': '2024-09-12T11:01:23.177344Z',
#      'start_time': '2024-09-12T11:01:23.100513Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-13T15:48:24.071899',
#      'end_time': '2024-12-13T15:48:24.113093',
#      'duration': 0.041194,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-13T15:48:24.073312Z',
#      'iopub.execute_input': '2024-12-13T15:48:24.073575Z',
#      'iopub.status.idle': '2024-12-13T15:48:24.111639Z',
#      'shell.execute_reply': '2024-12-13T15:48:24.110943Z'}},
#    'cell_type': 'code',
#    'source': "sdm = Graph().parse(os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')\nsdm += contract\nsdm.serialize(destination=os.path.join(base_dir, '../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')",
#    'id': '5e5b768e362cde6f',
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "<Graph identifier=N4471f7b177184479878b6d0f97a857ca (<class 'rdflib.graph.Graph'>)>"},
#      'execution_count': 13}],
#    'execution_count': 13}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.11.9',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {'folder': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Integration',
#     'dp_meta_path': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Integration/dp3.json'},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': '/home/acraf/psr/Fdatavalidation/Connector/ValidationFramework/experiments/MLpolicies/../../../../DataPlatformLayer/Integration/federator.ipynb',
#    'output_path': None,
#    'start_time': '2024-12-13T15:48:09.761795',
#    'end_time': '2024-12-13T15:48:24.333359',
#    'duration': 14.571564,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# ## DATA VALIDATION WORKFLOW

# %%
sdm = Graph().parse(os.path.join(base_dir, '../../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# Avaliable Common Data Models

# %%
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dp
WHERE {{
    # ?dp a tb:CommonDataModel .
}}
'''

q_res = sdm.query(query)

data_products = [row.dp.split("#")[1] for row in q_res]
data_products
# Out:
# ['Patient_Data']

# %% [markdown]
# The user selects a common data model for analysis

# %%
#dp = input("SELECT NAME OF THE COMMON DATA MODEL: ")
dp = "Patient_Data"

# %% [markdown]
# We retrive the data products that are mapped to the selected common data model through their data contracts

# %%
# Run the query
query = f'''
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>

SELECT ?dataset
WHERE {{
    # ?dataset tb:hasDC ?dcc .
    # ?dcc tb:hasPolicy ?p .
    # ?p odrl:prohibition|odrl:duty ?d .
    # ?d odrl:target ?t .
    # ?dp tb:hasFeature ?t .
    FILTER (?dp = ab:{dp})
}}
'''

qres = sdm.query(query)


data_products = [row.dataset.split("#")[1] for row in qres]

data_products = set(data_products)
data_products
# Out:
# {'modelpkl'}

# %% [markdown]
# ### PARSER

# %% [markdown]
# The parser generates a set of policy checkers $C$ for each data product $DP$ that is mapped to the selected common data model

# %%
for dp in data_products:
    print("DP", dp)
    pm.execute_notebook(
        os.path.join(base_dir, '../planner/planner.ipynb'),None, parameters={
            'folder': os.path.join(base_dir, '../planner/'),
            'dp': dp
        },
        log_output=False
    )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: dp
# Input notebook does not contain a cell with tag 'parameters'
# DP modelpkl
# Executing:   0%|          | 0/15 [00:00<?, ?cell/s]

# %% [markdown]
# ### TRANSLATOR

# %% [markdown]
# The translator takes a $pc$ and generates a UDF to scrutinize $DP$

# %%
sdm = Graph().parse(os.path.join(base_dir, '../../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %% [markdown]
# First we need to retrive all $pc \in C$ for each $DP$

# %%
def queryPC(dp):
    query = f'''
    PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
    PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
    PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
    
    SELECT ?pc ?ds
    WHERE {{
        # ?pc a tb:PolicyChecker .
        # ?pc tb:validates ?dp .
        FILTER (?dp = ab:{dp})        
    }}
    '''

    q_res = sdm.query(query)
    
    pcs = [row.pc for row in q_res]
    return pcs

# %% [markdown]
# Execute the translator for each $pc \in C$

# %%
for dp in data_products:
    pcs = queryPC(dp)
    for pc in pcs:
        print(pc.split("#")[1])
        pm.execute_notebook(             
            os.path.join(base_dir, '../translator/executor.ipynb'),None, parameters={
                'folder': '../../translator/',
                'pc' : pc.split("#")[1],
            },
            log_output=False
        )
# Out:
# Passed unknown parameter: folder
# Passed unknown parameter: pc
# Input notebook does not contain a cell with tag 'parameters'
# 0a501a01-717f-426d-92bd-bc15908e4b91
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]

# %% [markdown]
# ## DATA VALIDATION REPORTS

# %% [markdown]
# Since all the data validation metadata is stored in $\Delta$ it can be retrived through SPARQL queries

# %% [markdown]
# ### VALIDATION RESULT

# %% [markdown]
# The results for each DP and its associated policies can be retrived through the following query

# %%
sdm = Graph().parse(os.path.join(base_dir, '../../../FederatedComputationalGovernance/SemanticDataModel/sdm.ttl'), format='turtle')

# %%
query = """
PREFIX odrl: <http://www.w3.org/ns/odrl/2/>
PREFIX tb: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/tbox#>
PREFIX ab: <http://www.semanticweb.org/acraf/ontologies/2024/healthmesh/abox#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?dp ?p ?pc ?result
WHERE {
    # ?pc a tb:PolicyChecker .
    # ?pc tb:validates ?dp .
    # ?pc tb:accordingTo ?p .
    # ?pc tb:nextStep+ ?rep .
    # ?rep a tb:Report .
    # ?rep tb:result ?result .
}
"""

res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "Report",row["result"])
# Out:
# DP modelpkl P p4 Report False

# %% [markdown]
# ### CLARITY QUERIES

# %% [markdown]
# The user can query the metadata to retrive more details on how a Policy has been validated both logically and algorithmically

# %%
policy = "p2"

# %%
query = f"""
SELECT ?dp ?p ?pc ?op ?code
WHERE {{
     # ?pc a tb:PolicyChecker . 
     # ?pc tb:validates ?dp . 
     # ?pc tb:accordingTo ?p . 
     FILTER (?p = ab:{policy})
     # ?pc tb:nextStep+ ?op . 
     # ?op tb:hasTranslation ?imp . 
     # ?imp tb:hasCode ?codeclass . 
     # ?codeclass tb:code ?code . 
}}
"""


res = sdm.query(query)
for row in res:
    print("DP", row["dp"].split("#")[1], "P", row["p"].split("#")[1], "OP", row["op"].split("#")[1], "Code", row["code"])
# Out:
# DP UPENN-GBM_clinical_info_v21csv P p2 OP e63cba3e-602c-4364-8d04-bf0874912f56 Code pandas.read_csv(p)
# DP UPENN-GBM_clinical_info_v21csv P p2 OP 76185051-504c-4658-901b-c953e5bf310c Code (data[attr].count()/len(data))*100
# DP UPENN-GBM_clinical_info_v21csv P p2 OP bd08b7dd-fbc3-4315-b189-88d3838bdce7 Code data >= ro
# DP UPENN-GBM_clinical_info_v21csv P p2 OP bd08b7dd-fbc3-4315-b189-88d3838bdce7 Code data if not (data[attr] >= ro).all() else (data[attr] >= ro).all()
